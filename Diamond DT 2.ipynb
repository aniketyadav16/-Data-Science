# %% [markdown]
# # Diamond Dataset Analysis and Prediction
#
# ## Table of Contents
# 1. [Introduction](#introduction)
# 2. [Data Analysis](#data-analysis)
#    - [Data Overview](#data-overview)
#    - [Data Cleaning](#data-cleaning)
#    - [Feature Engineering](#feature-engineering)
#    - [Data Visualization](#data-visualization)
# 3. [Machine Learning](#machine-learning)
#    - [Problem Definition](#problem-definition)
#    - [Data Preparation for Machine Learning](#data-preparation-for-machine-learning)
#    - [Model Selection](#model-selection)
#    - [Model Evaluation](#model-evaluation)
#    - [Prediction](#prediction)
#
#
# ## Introduction
# Provide an overview of the project:
# - What is the dataset about?
# - Goals of the project:
#   - Analyze and visualize diamond attributes.
#   - Analysze trends with different attributes, how the target category, res, is affected by other attributes.
#   - Built a machine linear regression model to predict a specific parameter (e.g., price).
#   - Built a Logistic Regression model to predict if the given diamond is recommended to buy or not on the basis of a multiple features.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df =pd.read_csv(r'/Users/aniketyadav/Documents/DS/DataSets/diamonds.csv', header = 0)
df = df.drop("Unnamed: 0", axis =1 )
df['res'] = np.where((df['price'] > 4500) | (df['carat'] > 2.9), 1, 0)
data = pd.read_csv(r'/Users/aniketyadav/Documents/DS/DataSets/diamonds.csv', header = 0)
data = data.drop("Unnamed: 0", axis =1 )
data['res'] = np.where((data['price'] > 4500) | (data['carat'] > 2.9), 1, 0)
data
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        res
# 0        0
# 1        0
# ...

# %% [markdown]
# ### Data Dictionary:
#
# 1. **carat**: Weight of the diamond (0.2--5.01)
#
# 2.  **cut**: Quality of the cut (Fair, Good, Very Good, Premium, Ideal)
#
# 3. **color**: Diamond colour, from J (worst) to D (best)
#
# 4. **clarity**: A measurement of how clear the diamond is (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
#
# 5. **depth**: Total depth percentage = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
# 6. **table**: Width of top of diamond relative to widest point (43--95)
#
# 7. **price**: Price in US dollars (326 dollars -18,823 dollars)
#
# 8. **x**: Length in mm (0--10.74)
#
# 9. **y**: Width in mm (0--58.9)
#
# 10. **z**: Depth in mm (0--31.8)
#
# 11. **res**: If this Diamond is recommended to buy or not ( 1 = 'YES', 0 = 'NO' )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
#  10  res      53940 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z           res
# count  53940.000000  53940.000000  53940.000000
# mean       5.734526      3.538734      0.313404
# std        1.142135      0.705699      0.463881
# min        0.000000      0.000000      0.000000
# ...

# %%
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# res        0
# dtype: int64

# %% [markdown]
# <h2 style = 'color:Magenta'> Data Analysis </h2>

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True, bins=30, color='plum')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# 2. Price vs Carat
fig = px.scatter(x=df['carat'], y = df['price'], title='Price vs Carat', color=df['carat'], color_continuous_scale=px.colors.sequential.Darkmint)
fig.update_xaxes(title_text = 'Carat')
fig.update_yaxes(title_text= 'Price')
fig.update_layout(template='plotly_dark')
fig.update_layout(width=1000)
fig.show(renderer="png")

# 3. Price by Cut Quality
fig = px.box( df,x='cut',y='price',title='Price by Cut Quality',labels={'cut': 'Cut Quality', 'price': 'Price'},color='cut') 
fig.update_layout(showlegend=False)
fig.update_layout(template='plotly_dark')
fig.update_layout(height=600)
fig.update_layout(width=1000)
fig.show(renderer="png")


# 4. Price by Color
fig = px.box(
    df,
    x='color',
    y='price',
    title='Price by Color',
    labels={'color': 'Color', 'price': 'Price'},
    color='color' 
)
fig.update_layout(showlegend=False)
fig.update_layout(template='plotly_dark')
fig.update_layout(height=600)
fig.update_layout(width=1000)
fig.show(renderer="png")


fig = px.box(
    df,
    x='clarity',
    y='price',
    title='Price by Clarity',
    labels={'clarity': 'Clarity', 'price': 'Price'},
    color='clarity'
)
fig.update_layout(showlegend=False)
fig.update_layout(template='plotly_dark')
fig.update_layout(height=600)
fig.update_layout(width=1000)
fig.show(renderer="png")


import plotly.figure_factory as ff
correlation_matrix = df.select_dtypes(include='number').corr()


z = np.round(correlation_matrix.values, 2) 

fig = ff.create_annotated_heatmap(
    z=z,
    x=list(correlation_matrix.columns),
    y=list(correlation_matrix.index),
    colorscale='viridis',
    showscale=True,
    annotation_text=[[f"{value:.2f}" for value in row] for row in z], 
)

fig.update_layout(
    title='Correlation Matrix',
    xaxis_title='Features',
    yaxis_title='Features',
)
fig.update_layout(height=600)
fig.update_layout(width=1000)
fig.update_layout(template='plotly_dark')

fig.show(renderer="png")

# %%
fig = px.scatter(
    x=df['depth'], 
    y=df['table'], 
    size=df['price'], 
    marginal_y='violin',
    color_discrete_sequence=['cyan'],
    opacity=0.6,
    template='plotly_dark',
    height=550,
    width=1000,
    title='Depth vs Table with PRICE AS Marker Sizes'
)
fig.show(renderer='png')

# %%
fig = px.scatter(
    x=df['depth'], 
    y=df['table'], 
    color=df['cut'], 
    size=df['price'],  
    opacity=0.5,
    height=550,
    width=1000,
    symbol=df['clarity'],  
    template='plotly_dark',
    symbol_sequence=['circle', 'diamond', 'star', 'cross', 'triangle-up'],
    title='Depth vs Table by Cut and Clarity'
)
fig.update_layout(xaxis_title='Depth', yaxis_title='Table')
fig.show(renderer='png')

# %%
groupdata1 = data.groupby('cut')['price'].mean()
groupdata1 = groupdata1.reset_index()
gp = data.groupby('cut')['res'].sum().reset_index()

# %%
fig = px.pie(names = gp['cut'], values = gp['res'], hole = 0.5, template='plotly_dark', title='CUT VS RES')
fig.update_layout(title={'font':{'size':20, 'color':'gold','family':'Pacifico'}, 'x':0.5})
fig.show(renderer="png")

fig=px.pie(names=data['color'], values=data['res'], hole=0.5, template='plotly_dark', title='COLOR VS RES' )
fig.update_layout(title={'font':{'size':20, 'color':'gold','family':'Pacifico'}, 'x':0.5})
fig.show(renderer="png")

fig=px.pie(names = data['clarity'], values=data['res'], hole=0.5, template='plotly_dark', title = 'CLARITY VS RES')
fig.update_layout(title={'font':{'size':20, 'color':'gold','family':'Pacifico'}, 'x':0.5})
fig.show(renderer="png")


sns.barplot( x=data['clarity'], y =data['res'], hue=data['clarity'], palette='inferno')
# Out:
# <Axes: xlabel='clarity', ylabel='res'>

# %%
kn = data.pivot_table(index='cut', columns='clarity', values='price')
fig=px.line(kn, template='plotly_dark',title='Clarity V Price V Cut')
fig.update_layout(width=1100, height=500, title={'font':{'size':20, 'color':'cyan','family':'Pacifico'}, 'x':0.5})
fig.update_yaxes(title_text='Price')
fig.show(renderer="png")

# %%
plt.style.use("dark_background")
sns.barplot(kn, palette='viridis')
# Out:
# <Axes: xlabel='clarity'>

# %%
groupdata2 = data.groupby('carat')['price'].mean()
groupdata2=groupdata2.reset_index()

# %%
fig = px.line(x= groupdata2['carat'], y=groupdata2['price'], template='plotly_dark')
fig.update_xaxes(title_text='Carat')
fig.update_yaxes(title_text = 'Price in $')
fig.update_layout(width=1000)
fig.show(renderer='png')

# %%
fig = px.bar(x=groupdata1['cut'],y=groupdata1['price'], color=groupdata1['cut'], template='plotly_dark', opacity=0.9)
fig.update_xaxes(tickvals=[0,1,2,3,4], ticktext=['Fair','Good','Ideal','Premium','Very Good'], title_text='Cut')
fig.update_yaxes(title_text='Price')
fig.update_layout(showlegend=False)
fig.update_layout(height=600)
fig.update_layout(width=700)
fig.show(renderer="png")

# %%
groupdata3 = data.groupby(['cut','clarity'])['price'].mean()
groupdata3 = pd.DataFrame(groupdata3)
groupdata3.reset_index(inplace=True)

# %%
fig=px.line_polar(groupdata3, r='price', theta='clarity', color='cut', line_close=True,line_shape='spline', width=1000, height=1000, template='plotly_dark', color_discrete_sequence=['mistyrose','cyan','tomato','plum','magenta'], markers='o')
fig.show(renderer='png')

# %% [markdown]
# <h2 style = 'color:Magenta'> Machine Learning </h2>

# %% [markdown]
# <h3 style = 'color:tomato'> Linear Regression Model </h3>

# %%
from sklearn.linear_model import LinearRegression

from sklearn.linear_model import LogisticRegression

# %%
lrng_data = data[['carat','depth','x','y','z']]

lrng_data = lrng_data.loc[:40000,:]

price_rl = data.loc[:40000,'price']

model = LinearRegression()

model.fit(lrng_data, price_rl)
# Out:
# LinearRegression()

# %%
print(f'w1, w2, w3, w4 = {model.coef_}''\n')
print(f'b = {model.intercept_}')
# Out:
# w1, w2, w3, w4 = [ 9799.97326369  -172.22364175 -1128.20404327   104.43347618
#    212.59153906]
#
# b = 11971.661508147248

# %%
model.predict(lrng_data)
# Out:
# array([ 109.73809522,  234.07939217,  773.03447112, ..., 1219.94557707,
#        1014.75065888,  988.81789737])

# %%
def prediction(x):
    return model.predict(x)

# %%
data.carat.describe()
# Out:
# count    53940.000000
# mean         0.797940
# std          0.474011
# min          0.200000
# 25%          0.400000
# 50%          0.700000
# 75%          1.040000
# max          5.010000
# Name: carat, dtype: float64

# %%
def inp():    
    carat = float(input('enter carat: '))
    x = float(input('enter x (Length in mm):'))
    y = float(input('enter y (Width in mm): '))
    z = float(input('enter z (Depth in mm): '))
    depth = z / ((x+y)/2)
    pre = pd.DataFrame([[carat, depth, x, y, z]], columns = ['carat','depth','x','y','z'])
    return prediction(pre).round()

# %% [markdown]
# <h4 style = 'color:skyblue'> Call inp() to predict The PRICE of a DIAMOND </h4>

# %% [markdown]
# <h3  > Logistic Regression</h3>

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %%
model2 = LogisticRegression()

# %%
res_dat = data.loc[:40000, 'res']
lrng_data2 = data.loc[:40000, ['price','carat','depth','x','y','z']]
trn_res_dat = data.loc[40001:, 'res']
trn_lrng_data2 = data.loc[40001:, ['price','carat','depth','x','y','z']]

# %%
model2.fit(lrng_data2, res_dat)
# Out:
# LogisticRegression()

# %%
model2.score(lrng_data2, res_dat)
# Out:
# 0.9950001249968751

# %%
model2.score(trn_lrng_data2, trn_res_dat)
# Out:
# 0.9999282588420977

# %%
def inp2():
        price=float(input('Enter Price:'))
        carat=float(input('Enter Carat:'))
        x=float(input('Enter x (Length):'))    
        y=float(input('Enter y (width):'))
        z=float(input('Enter z (Depth)'))
        depth = z / ((x+y)/2)
        predic = model2.predict([[price,carat,depth,x,y,z]])
        if predic == 1:
            print('It is RECOMMENDED to BUY this DIAMOND!!!')
        else:
            print("DO NOT BUY THIS AT ALL!!!")

# %%
def inp3(dataset):
     dataset['predictions'] = model2.predict(dataset)
     return dataset

# %%
inp3(trn_lrng_data2)
# Out:
#        price  carat  depth     x     y     z  predictions
# 40001   1107   0.41   62.3  4.78  4.75  2.97            0
# 40002   1107   0.41   61.8  4.79  4.75  2.95            0
# 40003   1107   0.41   62.6  4.81  4.75  2.99            0
# 40004   1107   0.41   63.2  4.76  4.74  3.00            0
# 40005   1107   0.41   61.9  4.76  4.74  2.94            0
# ...      ...    ...    ...   ...   ...   ...          ...
# 53935   2757   0.72   60.8  5.75  5.76  3.50            0
# 53936   2757   0.72   63.1  5.69  5.75  3.61            0
# 53937   2757   0.70   62.8  5.66  5.68  3.56            0
# 53938   2757   0.86   61.0  6.15  6.12  3.74            0
# 53939   2757   0.75   62.2  5.83  5.87  3.64            0
#
# [13939 rows x 7 columns]

# %% [markdown]
# <h4 style = 'color:skyblue'> Try Yourself By Calling inp2(), use inp3(dataset) to predict for a whole dataset </h4>
